# %%
import numpy as np
import pandas as pd
import sklearn.model_selection

# %%
data = pd.read_excel('../data/processed/cleaned_disaster_dataset.xlsx')
data
# Out:
#               disno. historic disaster_group disaster_subgroup  \
# 0      1900-0003-USA      Yes        Natural    Meteorological
# 1      1900-0006-JAM      Yes        Natural      Hydrological
# 2      1900-0007-JAM      Yes        Natural        Biological
# 3      1900-0008-JPN      Yes        Natural       Geophysical
# 4      1900-0009-TUR      Yes        Natural       Geophysical
# ...              ...      ...            ...               ...
# 17751  2000-0036-CHN       No        Natural       Geophysical
# 17752  2000-0009-IRN       No        Natural    Meteorological
# 17753  1999-9388-UGA      Yes        Natural    Climatological
# 17754  1999-9388-SOM       No        Natural    Climatological
# 17755  2009-0616-AUS       No        Natural    Meteorological
#
#              disaster_type  disaster_subtype     external_ids  \
# 0                    Storm  Tropical cyclone              NaN
# 1                    Flood   Flood (General)              NaN
# 2                 Epidemic     Viral disease              NaN
# 3        Volcanic activity          Ash fall              NaN
# 4               Earthquake   Ground movement              NaN
# ...                    ...               ...              ...
# 17751           Earthquake   Ground movement  USGS:usp0009mq6
# 17752                Storm   Storm (General)              NaN
# 17753              Drought           Drought              NaN
# 17754              Drought           Drought              NaN
# 17755  Extreme temperature         Heat wave              NaN
#
#             event_name                     country    region origin  \
# 0                  NaN    United States of America  Americas    NaN
# 1                  NaN                     Jamaica  Americas    NaN
# 2      Gastroenteritis                     Jamaica  Americas    NaN
# 3                  NaN                       Japan      Asia    NaN
# 4                  NaN                     Türkiye      Asia    NaN
# ...                ...                         ...       ...    ...
# 17751              NaN                       China      Asia    NaN
# 17752              NaN  Iran (Islamic Republic of)      Asia    NaN
# 17753              NaN                      Uganda    Africa    NaN
# 17754              NaN                     Somalia    Africa    NaN
# 17755              NaN                   Australia   Oceania    NaN
#
#                associated_types  magnitude   magnitude_scale  latitude  \
# 0      Avalanche (Snow, Debris)      220.0               Kph       NaN
# 1                           NaN        NaN               Km2       NaN
# 2                           NaN        NaN        Vaccinated       NaN
# 3                           NaN        NaN               NaN       NaN
# 4                           NaN        5.9  Moment Magnitude    40.300
# ...                         ...        ...               ...       ...
# 17751                       NaN        4.9  Moment Magnitude    24.263
# 17752                      Fire      120.0               Kph       NaN
# 17753                    Famine        NaN               Km2       NaN
# 17754             Food shortage        NaN               Km2       NaN
# 17755                       NaN       48.8                °C       NaN
#
#        longitude  start_year  start_month  \
# 0            NaN        1900          9.0
# 1            NaN        1900          1.0
# 2            NaN        1900          1.0
# 3            NaN        1900          7.0
# 4         43.100        1900          7.0
# ...          ...         ...          ...
# 17751    103.797        2000          1.0
# 17752        NaN        2000          1.0
# 17753        NaN        1999          8.0
# 17754        NaN        2000          1.0
# 17755        NaN        2009          1.0
#
#                                              admin_units  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17751  [{"adm2_code":13308,"adm2_name":"Honghe Hani a...
# 17752           [{"adm1_code":1545,"adm1_name":"Gilan"}]
# 17753  [{"adm1_code":743,"adm1_name":"Abim"},{"adm1_c...
# 17754  [{"adm1_code":2691,"adm1_name":"Bay"},{"adm1_c...
# 17755  [{"adm1_code":470,"adm1_name":"New South Wales...
#
#                                         gadm_admin_units
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17751  [{"gid_2":"CHN.30.13_1","migration_date":"2025...
# 17752  [{"gid_1":"IRN.8_1","migration_date":"2025-12-...
# 17753  [{"gid_2":"UGA.28.1_1","migration_date":"2025-...
# 17754  [{"gid_1":"SOM.5_1","migration_date":"2025-12-...
# 17755  [{"gid_1":"AUS.10_1","migration_date":"2025-12...
#
# [17756 rows x 20 columns]

# %%
data_train, data_test = sklearn.model_selection.train_test_split(
    data,
    train_size   = 0.70,
    shuffle      = True ,
    stratify=data["disaster_type"],
    random_state = 0
)

# %%
data_train.to_excel('../data/processed/disaster_prediction_train.xlsx', index=False)
data_test.to_excel('../data/processed/disaster_prediction_test.xlsx', index=False)
