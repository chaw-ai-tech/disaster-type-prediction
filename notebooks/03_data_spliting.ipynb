# %%
import numpy as np
import pandas as pd
import sklearn.model_selection

# %%
data = pd.read_excel('../data/processed/cleaned_disaster_dataset.xlsx')
data
# Out:
#              disaster_type                     country    region origin  \
# 0                    Storm    United States of America  Americas    NaN
# 1                    Flood                     Jamaica  Americas    NaN
# 2                 Epidemic                     Jamaica  Americas    NaN
# 3        Volcanic activity                       Japan      Asia    NaN
# 4               Earthquake                     Türkiye      Asia    NaN
# ...                    ...                         ...       ...    ...
# 17751           Earthquake                       China      Asia    NaN
# 17752                Storm  Iran (Islamic Republic of)      Asia    NaN
# 17753              Drought                      Uganda    Africa    NaN
# 17754              Drought                     Somalia    Africa    NaN
# 17755  Extreme temperature                   Australia   Oceania    NaN
#
#       ofda/bha_response appeal declaration  magnitude   magnitude_scale  \
# 0                    No     No          No      220.0               Kph
# 1                    No     No          No        NaN               Km2
# 2                    No     No          No        NaN        Vaccinated
# 3                    No     No          No        NaN               NaN
# 4                    No     No          No        5.9  Moment Magnitude
# ...                 ...    ...         ...        ...               ...
# 17751                No     No          No        4.9  Moment Magnitude
# 17752                No     No          No      120.0               Kph
# 17753                No     No          No        NaN               Km2
# 17754                No     No          No        NaN               Km2
# 17755                No     No          No       48.8                °C
#
#        latitude  longitude  start_year  start_month  end_year  end_month  \
# 0           NaN        NaN        1900          9.0      1900        9.0
# 1           NaN        NaN        1900          1.0      1900        1.0
# 2           NaN        NaN        1900          1.0      1900        1.0
# 3           NaN        NaN        1900          7.0      1900        7.0
# 4        40.300     43.100        1900          7.0      1900        7.0
# ...         ...        ...         ...          ...       ...        ...
# 17751    24.263    103.797        2000          1.0      2000        1.0
# 17752       NaN        NaN        2000          1.0      2000        1.0
# 17753       NaN        NaN        1999          8.0      2001        NaN
# 17754       NaN        NaN        2000          1.0      2001        NaN
# 17755       NaN        NaN        2009          1.0      2009        2.0
#
#        total_deaths  total_damage_('000_us$)  \
# 0            6000.0                  30000.0
# 1             300.0                      NaN
# 2              30.0                      NaN
# 3              30.0                      NaN
# 4             140.0                      NaN
# ...             ...                      ...
# 17751           1.0                    483.0
# 17752           3.0                      NaN
# 17753         115.0                      NaN
# 17754          21.0                      NaN
# 17755         347.0                      NaN
#
#        total_damage,_adjusted_('000_us$)        cpi
# 0                              1131126.0   2.652223
# 1                                    NaN   2.652223
# 2                                    NaN   2.652223
# 3                                    NaN   2.652223
# 4                                    NaN   2.652223
# ...                                  ...        ...
# 17751                              880.0  54.895152
# 17752                                NaN  54.895152
# 17753                                NaN  53.101972
# 17754                                NaN  54.895152
# 17755                                NaN  68.391643
#
# [17756 rows x 19 columns]

# %%
data_train, data_test = sklearn.model_selection.train_test_split(
    data,
    train_size   = 0.70,
    shuffle      = True ,
    stratify=data["disaster_type"],
    random_state = 0
)

# %%
data_train.to_excel('../data/processed/disaster_prediction_train.xlsx', index=False)
data_test.to_excel('../data/processed/disaster_prediction_test.xlsx', index=False)
